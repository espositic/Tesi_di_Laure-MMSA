# %%
#IMPORT DELLE LIBRERIE
import numpy as np 
import os
import tarfile
import numpy as np
import matplotlib.pyplot as plt

import skimage.transform as trans
from skimage import io, color
from skimage.util import random_noise

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras

from sklearn.datasets import fetch_lfw_people
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#DOWNLOAD DEL DATASET
lfw_dataset=fetch_lfw_people(resize=0.256,download_if_missing=True,slice_=None,color=True)
print(lfw_dataset.images.shape)
X=lfw_dataset.images
y=lfw_dataset.target


#SPLIT DEL DATASET PER IL TEST SET
X_train, X_test, y_train, y_test = train_test_split(X, y,
    test_size=0.2)

#SPLIT DEL DATASET PER IL VALIDATION SET
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
    test_size=0.1)
# Out:
# (13233, 64, 64, 3)

# %%
#DIMENSIONI DEL TRAINING SET
X_train.shape
# Out:
# (9527, 64, 64, 3)

# %%
#DIMENSIONI DEL TEST SET
X_test.shape
# Out:
# (2647, 64, 64, 3)

# %%
#DIMENSIONI DEL VALIDATION SET
X_val.shape
# Out:
# (1059, 64, 64, 3)

# %%
#AGGIUNGIAMO IL RUMORE ALLE IMMAGINI
noise_factor = 0.2

X_train_noisy = random_noise(X_train, mode="s&p",clip=True, amount=noise_factor)
X_test_noisy = random_noise(X_test, mode="s&p",clip=True, amount=noise_factor)
X_val_noisy = random_noise(X_val, mode="s&p",clip=True, amount=noise_factor)

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TRAINING SET
n = 10

plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_train[i].reshape(64, 64,3))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TRAINING SET COL RUMORE
n = 10

plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_train_noisy[i].reshape(64, 64,3))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
def selective_kernel_feature_fusion(
    multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3
):
    channels = list(multi_scale_feature_1.shape)[-1]
    combined_feature = Add()(
        [multi_scale_feature_1, multi_scale_feature_2, multi_scale_feature_3]
    )
    gap = GlobalAveragePooling2D()(combined_feature)
    channel_wise_statistics = tf.reshape(gap, shape=(-1, 1, 1, channels))
    compact_feature_representation = Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(channel_wise_statistics)
    feature_descriptor_1 = Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_2 = Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_descriptor_3 = Conv2D(
        channels, kernel_size=(1, 1), activation="softmax"
    )(compact_feature_representation)
    feature_1 = multi_scale_feature_1 * feature_descriptor_1
    feature_2 = multi_scale_feature_2 * feature_descriptor_2
    feature_3 = multi_scale_feature_3 * feature_descriptor_3
    aggregated_feature = Add()([feature_1, feature_2, feature_3])
    return aggregated_feature

# %%
def spatial_attention_block(input_tensor):
    average_pooling = tf.reduce_max(input_tensor, axis=-1)
    average_pooling = tf.expand_dims(average_pooling, axis=-1)
    max_pooling = tf.reduce_mean(input_tensor, axis=-1)
    max_pooling = tf.expand_dims(max_pooling, axis=-1)
    concatenated = Concatenate(axis=-1)([average_pooling, max_pooling])
    feature_map = Conv2D(1, kernel_size=(1, 1))(concatenated)
    feature_map = tf.nn.sigmoid(feature_map)
    return input_tensor * feature_map


def channel_attention_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    average_pooling = GlobalAveragePooling2D()(input_tensor)
    feature_descriptor = tf.reshape(average_pooling, shape=(-1, 1, 1, channels))
    feature_activations = Conv2D(
        filters=channels // 8, kernel_size=(1, 1), activation="relu"
    )(feature_descriptor)
    feature_activations = Conv2D(
        filters=channels, kernel_size=(1, 1), activation="sigmoid"
    )(feature_activations)
    return input_tensor * feature_activations


def dual_attention_unit_block(input_tensor):
    channels = list(input_tensor.shape)[-1]
    feature_map = Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(input_tensor)
    feature_map = Conv2D(channels, kernel_size=(3, 3), padding="same")(
        feature_map
    )
    channel_attention = channel_attention_block(feature_map)
    spatial_attention = spatial_attention_block(feature_map)
    concatenation = Concatenate(axis=-1)([channel_attention, spatial_attention])
    concatenation = Conv2D(channels, kernel_size=(1, 1))(concatenation)
    return Add()([input_tensor, concatenation])

# %%
# Recursive Residual Modules


def down_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = MaxPooling2D()(main_branch)
    main_branch = Conv2D(channels * 2, kernel_size=(1, 1))(main_branch)
    skip_branch = MaxPooling2D()(input_tensor)
    skip_branch = Conv2D(channels * 2, kernel_size=(1, 1))(skip_branch)
    return Add()([skip_branch, main_branch])


def up_sampling_module(input_tensor):
    channels = list(input_tensor.shape)[-1]
    main_branch = Conv2D(channels, kernel_size=(1, 1), activation="relu")(
        input_tensor
    )
    main_branch = Conv2D(
        channels, kernel_size=(3, 3), padding="same", activation="relu"
    )(main_branch)
    main_branch = UpSampling2D()(main_branch)
    main_branch = Conv2D(channels // 2, kernel_size=(1, 1))(main_branch)
    skip_branch = UpSampling2D()(input_tensor)
    skip_branch = Conv2D(channels // 2, kernel_size=(1, 1))(skip_branch)
    return Add()([skip_branch, main_branch])


# MRB Block
def multi_scale_residual_block(input_tensor, channels):
    # features
    level1 = input_tensor
    level2 = down_sampling_module(input_tensor)
    level3 = down_sampling_module(level2)
    # DAU
    level1_dau = dual_attention_unit_block(level1)
    level2_dau = dual_attention_unit_block(level2)
    level3_dau = dual_attention_unit_block(level3)
    # SKFF
    level1_skff = selective_kernel_feature_fusion(
        level1_dau,
        up_sampling_module(level2_dau),
        up_sampling_module(up_sampling_module(level3_dau)),
    )
    level2_skff = selective_kernel_feature_fusion(
        down_sampling_module(level1_dau), level2_dau, up_sampling_module(level3_dau)
    )
    level3_skff = selective_kernel_feature_fusion(
        down_sampling_module(down_sampling_module(level1_dau)),
        down_sampling_module(level2_dau),
        level3_dau,
    )
    # DAU 2
    level1_dau_2 = dual_attention_unit_block(level1_skff)
    level2_dau_2 = up_sampling_module((dual_attention_unit_block(level2_skff)))
    level3_dau_2 = up_sampling_module(
        up_sampling_module(dual_attention_unit_block(level3_skff))
    )
    # SKFF 2
    skff_ = selective_kernel_feature_fusion(level1_dau_2, level2_dau_2, level3_dau_2)
    conv = Conv2D(channels, kernel_size=(3, 3), padding="same")(skff_)
    return Add()([input_tensor, conv])

# %%
def recursive_residual_group(input_tensor, num_mrb, channels):
    conv1 = Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_mrb):
        conv1 = multi_scale_residual_block(conv1, channels)
    conv2 = Conv2D(channels, kernel_size=(3, 3), padding="same")(conv1)
    return Add()([conv2, input_tensor])


def mirnet_model(num_rrg, num_mrb, channels):
    input_tensor = keras.Input(shape=[None, None, 3])
    x1 = Conv2D(channels, kernel_size=(3, 3), padding="same")(input_tensor)
    for _ in range(num_rrg):
        x1 = recursive_residual_group(x1, num_mrb, channels)
    conv = Conv2D(3, kernel_size=(3, 3), padding="same")(x1)
    output_tensor = Add()([input_tensor, conv])
    return keras.Model(input_tensor, output_tensor)


model = mirnet_model(num_rrg=3, num_mrb=2, channels=64)

# %%
def charbonnier_loss(y_true, y_pred):
    return tf.reduce_mean(tf.sqrt(tf.square(y_true - y_pred) + tf.square(1e-3)))


def peak_signal_noise_ratio(y_true, y_pred):
    return tf.image.psnr(y_pred, y_true, max_val=255.0)


optimizer = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(
    optimizer=optimizer, loss=charbonnier_loss, metrics=[peak_signal_noise_ratio]
)

# %%
#TRAINING DEL MODELLO
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0001, patience=3)
history = model.fit(X_train_noisy, X_train, epochs=100, batch_size=16, validation_data=(X_val_noisy,X_val), callbacks=[callback])
# Out:
# Epoch 1/100
# 596/596 [==============================] - 637s 1s/step - loss: 0.0565 - peak_signal_noise_ratio: 69.7323 - val_loss: 0.0495 - val_peak_signal_noise_ratio: 70.6996
# Epoch 2/100
# 596/596 [==============================] - 629s 1s/step - loss: 0.0394 - peak_signal_noise_ratio: 72.1526 - val_loss: 0.0355 - val_peak_signal_noise_ratio: 72.9477
# Epoch 3/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0312 - peak_signal_noise_ratio: 73.8553 - val_loss: 0.0279 - val_peak_signal_noise_ratio: 74.6932
# Epoch 4/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0259 - peak_signal_noise_ratio: 75.3655 - val_loss: 0.0240 - val_peak_signal_noise_ratio: 76.0325
# Epoch 5/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0216 - peak_signal_noise_ratio: 76.9303 - val_loss: 0.0195 - val_peak_signal_noise_ratio: 77.7727
# Epoch 6/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0177 - peak_signal_noise_ratio: 78.6307 - val_loss: 0.0159 - val_peak_signal_noise_ratio: 79.4713
# Epoch 7/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0150 - peak_signal_noise_ratio: 80.0905 - val_loss: 0.0142 - val_peak_signal_noise_ratio: 80.6731
# Epoch 8/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0134 - peak_signal_noise_ratio: 81.1957 - val_loss: 0.0124 - val_peak_signal_noise_ratio: 81.7798
# Epoch 9/100
# 596/596 [==============================] - 609s 1s/step - loss: 0.0120 - peak_signal_noise_ratio: 82.1542 - val_loss: 0.0112 - val_peak_signal_noise_ratio: 82.6443
# Epoch 10/100
# 596/596 [==============================] - 629s 1s/step - loss: 0.0110 - peak_signal_noise_ratio: 82.9060 - val_loss: 0.0106 - val_peak_signal_noise_ratio: 83.2214
# Epoch 11/100
# 596/596 [==============================] - 629s 1s/step - loss: 0.0102 - peak_signal_noise_ratio: 83.4946 - val_loss: 0.0099 - val_peak_signal_noise_ratio: 83.7026
# Epoch 12/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0095 - peak_signal_noise_ratio: 84.0130 - val_loss: 0.0095 - val_peak_signal_noise_ratio: 84.1061
# Epoch 13/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0090 - peak_signal_noise_ratio: 84.4484 - val_loss: 0.0088 - val_peak_signal_noise_ratio: 84.5897
# Epoch 14/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0085 - peak_signal_noise_ratio: 84.8330 - val_loss: 0.0082 - val_peak_signal_noise_ratio: 85.0333
# Epoch 15/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0081 - peak_signal_noise_ratio: 85.1889 - val_loss: 0.0081 - val_peak_signal_noise_ratio: 85.2490
# Epoch 16/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0077 - peak_signal_noise_ratio: 85.5560 - val_loss: 0.0077 - val_peak_signal_noise_ratio: 85.6359
# Epoch 17/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0074 - peak_signal_noise_ratio: 85.8720 - val_loss: 0.0076 - val_peak_signal_noise_ratio: 85.8376
# Epoch 18/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0071 - peak_signal_noise_ratio: 86.1778 - val_loss: 0.0071 - val_peak_signal_noise_ratio: 86.1576
# Epoch 19/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0069 - peak_signal_noise_ratio: 86.4489 - val_loss: 0.0068 - val_peak_signal_noise_ratio: 86.4834
# Epoch 20/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0066 - peak_signal_noise_ratio: 86.7263 - val_loss: 0.0067 - val_peak_signal_noise_ratio: 86.7071
# Epoch 21/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0064 - peak_signal_noise_ratio: 86.9824 - val_loss: 0.0063 - val_peak_signal_noise_ratio: 87.0363
# Epoch 22/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0062 - peak_signal_noise_ratio: 87.2251 - val_loss: 0.0062 - val_peak_signal_noise_ratio: 87.2086
# Epoch 23/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0060 - peak_signal_noise_ratio: 87.4615 - val_loss: 0.0058 - val_peak_signal_noise_ratio: 87.5037
# Epoch 24/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0058 - peak_signal_noise_ratio: 87.6963 - val_loss: 0.0057 - val_peak_signal_noise_ratio: 87.6784
# Epoch 25/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0056 - peak_signal_noise_ratio: 87.9712 - val_loss: 0.0054 - val_peak_signal_noise_ratio: 87.9733
# Epoch 26/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0054 - peak_signal_noise_ratio: 88.2229 - val_loss: 0.0054 - val_peak_signal_noise_ratio: 88.1217
# Epoch 27/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0052 - peak_signal_noise_ratio: 88.4727 - val_loss: 0.0053 - val_peak_signal_noise_ratio: 88.2588
# Epoch 28/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0050 - peak_signal_noise_ratio: 88.6571 - val_loss: 0.0049 - val_peak_signal_noise_ratio: 88.6801
# Epoch 29/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0048 - peak_signal_noise_ratio: 88.8969 - val_loss: 0.0048 - val_peak_signal_noise_ratio: 88.8559
# Epoch 30/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0047 - peak_signal_noise_ratio: 89.1035 - val_loss: 0.0045 - val_peak_signal_noise_ratio: 89.0841
# Epoch 31/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0045 - peak_signal_noise_ratio: 89.2915 - val_loss: 0.0046 - val_peak_signal_noise_ratio: 89.1390
# Epoch 32/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0044 - peak_signal_noise_ratio: 89.4580 - val_loss: 0.0045 - val_peak_signal_noise_ratio: 89.2331
# Epoch 33/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0043 - peak_signal_noise_ratio: 89.6155 - val_loss: 0.0045 - val_peak_signal_noise_ratio: 89.1888
# Epoch 34/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0041 - peak_signal_noise_ratio: 89.7880 - val_loss: 0.0041 - val_peak_signal_noise_ratio: 89.6250
# Epoch 35/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0040 - peak_signal_noise_ratio: 89.9568 - val_loss: 0.0039 - val_peak_signal_noise_ratio: 89.8365
# Epoch 36/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0039 - peak_signal_noise_ratio: 90.1101 - val_loss: 0.0039 - val_peak_signal_noise_ratio: 89.8126
# Epoch 37/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0038 - peak_signal_noise_ratio: 90.2728 - val_loss: 0.0038 - val_peak_signal_noise_ratio: 89.9615
# Epoch 38/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0037 - peak_signal_noise_ratio: 90.4026 - val_loss: 0.0038 - val_peak_signal_noise_ratio: 89.9770
# Epoch 39/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0036 - peak_signal_noise_ratio: 90.5801 - val_loss: 0.0037 - val_peak_signal_noise_ratio: 90.2006
# Epoch 40/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0036 - peak_signal_noise_ratio: 90.7052 - val_loss: 0.0036 - val_peak_signal_noise_ratio: 90.3511
# Epoch 41/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0035 - peak_signal_noise_ratio: 90.8493 - val_loss: 0.0035 - val_peak_signal_noise_ratio: 90.5047
# Epoch 42/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0034 - peak_signal_noise_ratio: 90.9954 - val_loss: 0.0034 - val_peak_signal_noise_ratio: 90.5823
# Epoch 43/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0034 - peak_signal_noise_ratio: 91.1095 - val_loss: 0.0035 - val_peak_signal_noise_ratio: 90.6090
# Epoch 44/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0033 - peak_signal_noise_ratio: 91.2400 - val_loss: 0.0034 - val_peak_signal_noise_ratio: 90.8303
# Epoch 45/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0033 - peak_signal_noise_ratio: 91.3648 - val_loss: 0.0033 - val_peak_signal_noise_ratio: 90.9294
# Epoch 46/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0032 - peak_signal_noise_ratio: 91.4777 - val_loss: 0.0033 - val_peak_signal_noise_ratio: 90.9573
# Epoch 47/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0032 - peak_signal_noise_ratio: 91.5864 - val_loss: 0.0033 - val_peak_signal_noise_ratio: 90.9942
# Epoch 48/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0031 - peak_signal_noise_ratio: 91.6916 - val_loss: 0.0032 - val_peak_signal_noise_ratio: 91.1803
# Epoch 49/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0031 - peak_signal_noise_ratio: 91.8198 - val_loss: 0.0033 - val_peak_signal_noise_ratio: 91.0881
# Epoch 50/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0030 - peak_signal_noise_ratio: 91.9153 - val_loss: 0.0031 - val_peak_signal_noise_ratio: 91.3028
# Epoch 51/100
# 596/596 [==============================] - 607s 1s/step - loss: 0.0030 - peak_signal_noise_ratio: 92.0208 - val_loss: 0.0032 - val_peak_signal_noise_ratio: 91.3267
# Epoch 52/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0030 - peak_signal_noise_ratio: 92.1431 - val_loss: 0.0031 - val_peak_signal_noise_ratio: 91.4229
# Epoch 53/100
# 596/596 [==============================] - 608s 1s/step - loss: 0.0029 - peak_signal_noise_ratio: 92.2251 - val_loss: 0.0032 - val_peak_signal_noise_ratio: 91.4149
# Epoch 54/100
# 596/596 [==============================] - 628s 1s/step - loss: 0.0029 - peak_signal_noise_ratio: 92.3341 - val_loss: 0.0032 - val_peak_signal_noise_ratio: 91.3883

# %%
#TEST DEL MODELLO SUL TEST SET
predict = model.predict(X_test_noisy)
# Out:
# 83/83 [==============================] - 56s 588ms/step

# %%
predict.shape
# Out:
# (2647, 64, 64, 3)

# %%
n=10

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TEST SET
plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_test[i].reshape(64, 64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TEST SET COL RUMORE
plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_test_noisy[i].reshape(64, 64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TEST SET SENZA RUMORE (OUTPUT DELLA UNET)
plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(predict[i].reshape(64, 64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
NUMBER_OF_TEST_IMAGES = len(X_test)

mse = mean_squared_error(X_test.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3), predict.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3))
mae = mean_absolute_error(X_test.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3), predict.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3))
rmse = np.sqrt(mean_squared_error(X_test.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3), predict.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3)))

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 5.3983134e-05
# Mean Absolute Error: 0.0027816137
# Root Mean Squared Error: 0.0073473216

# %%
plt.figure(figsize = (11,7))
x = ["MSE","MAE","RMSE"]
y = [mse,mae,rmse]
plt.barh(x, y)
  
for index, value in enumerate(y):
    plt.text(value, index,
             str(value)[:7])
plt.show()
