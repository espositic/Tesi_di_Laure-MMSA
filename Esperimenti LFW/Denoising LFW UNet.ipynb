# %%
#IMPORT DELLE LIBRERIE
import numpy as np 
import os
import tarfile
import numpy as np
import matplotlib.pyplot as plt

import skimage.transform as trans
from skimage import io, color
from skimage.util import random_noise

from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras import backend as keras

from sklearn.datasets import fetch_lfw_people
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#DOWNLOAD DEL DATASET
lfw_dataset=fetch_lfw_people(resize=0.256,download_if_missing=True,slice_=None,color=True)
print(lfw_dataset.images.shape)
X=lfw_dataset.images
y=lfw_dataset.target


#SPLIT DEL DATASET PER IL TEST SET
X_train, X_test, y_train, y_test = train_test_split(X, y,
    test_size=0.2)

#SPLIT DEL DATASET PER IL VALIDATION SET
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
    test_size=0.1)

#MODIFICA DI COME VENGONO SALVATE LE IMMAGINI IN MEMORIA
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255
X_val = X_val.astype('float32') / 255
# Out:
# (13233, 64, 64, 3)

# %%
#DIMENSIONI DEL TRAINING SET
X_train.shape
# Out:
# (9527, 64, 64, 3)

# %%
#DIMENSIONI DEL TEST SET
X_test.shape
# Out:
# (2647, 64, 64, 3)

# %%
#DIMENSIONI DEL VALIDATION SET
X_val.shape
# Out:
# (1059, 64, 64, 3)

# %%
#AGGIUNGIAMO IL RUMORE ALLE IMMAGINI
noise_factor = 0.2

X_train_noisy = random_noise(X_train, mode="s&p",clip=True, amount=noise_factor)
X_test_noisy = random_noise(X_test, mode="s&p",clip=True, amount=noise_factor)
X_val_noisy = random_noise(X_val, mode="s&p",clip=True, amount=noise_factor)

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TRAINING SET
n = 10

plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_train[i].reshape(64, 64,3))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TRAINING SET COL RUMORE
n = 10

plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_train_noisy[i].reshape(64, 64,3))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#MODELLO U-NET
input_size = X_train.shape[1:]
inputs = Input(input_size)
conv1 = Conv2D(64,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(inputs)
conv1 = Conv2D(64,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv1)
pool1 = MaxPooling2D((2,2))(conv1) 
conv2 = Conv2D(128,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(pool1)
conv2 = Conv2D(128,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv2)
pool2 = MaxPooling2D((2,2))(conv2)
conv3 = Conv2D(256,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(pool2)
conv3 = Conv2D(256,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv3)
pool3 = MaxPooling2D((2,2))(conv3)   
conv4 = Conv2D(512,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(pool3)
conv4 = Conv2D(512,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling2D((2,2))(drop4)

conv5 = Conv2D(1024,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(pool4)
conv5 = Conv2D(1024,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv5)
drop5 = Dropout(0.5)(conv5)

up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
merge6 = concatenate([up6, drop4], axis = 3)
conv6 = Conv2D(512,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(merge6)
conv6 = Conv2D(512,(3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv6)
    
up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
merge7 = concatenate([up7, conv3], axis = 3)
conv7 = Conv2D(256, (3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(merge7)
conv7 = Conv2D(256, (3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv7)
    
up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
merge8 = concatenate([up8, conv2], axis = 3)
conv8 = Conv2D(128, (3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(merge8)
conv8 = Conv2D(128, (3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv8)
    
up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
merge9 = concatenate([up9, conv1], axis = 3)
conv9 = Conv2D(64, (3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(merge9)
conv9 = Conv2D(64, (3,3), activation='relu', padding='same', kernel_initializer = 'he_normal')(conv9)

conv10 = Conv2D(3, (1,1), padding='same', activation='sigmoid')(conv9)

model = Model(inputs, conv10)

model.compile(optimizer = Adam(lr = 1e-4), loss = 'mse')
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 64, 64, 64)   1792        ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 32, 32, 64)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 32, 32, 128)  73856       ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 512)    1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 8, 8, 512)    2359808     ['conv2d_6[0][0]']
#
#  dropout (Dropout)              (None, 8, 8, 512)    0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 4, 4, 512)   0           ['dropout[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 1024)   4719616     ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 1024)   9438208     ['conv2d_8[0][0]']
#
#  dropout_1 (Dropout)            (None, 4, 4, 1024)   0           ['conv2d_9[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 8, 8, 1024)   0           ['dropout_1[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 8, 8, 512)    2097664     ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 1024)   0           ['conv2d_10[0][0]',
#                                                                   'dropout[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 8, 8, 512)    4719104     ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 8, 8, 512)    2359808     ['conv2d_11[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 512)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 256)  524544      ['up_sampling2d_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 512)  0           ['conv2d_13[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_14[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0          ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 128)  131200      ['up_sampling2d_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_16[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_2[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_17[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 64, 64, 64)   32832       ['up_sampling2d_3[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_19[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 3)    195         ['conv2d_21[0][0]']
#
# ==================================================================================================
# Total params: 31,031,875
# Trainable params: 31,031,875
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#TRAINING DEL MODELLO
history = model.fit(X_train_noisy, X_train, epochs=100, batch_size=16, validation_data=(X_val_noisy,X_val))
# Out:
# Epoch 1/100
# 596/596 [==============================] - 80s 113ms/step - loss: 0.0087 - val_loss: 0.0059
# Epoch 2/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 3/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0040 - val_loss: 0.0047
# Epoch 4/100
# 596/596 [==============================] - 63s 106ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 5/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0032 - val_loss: 0.0034
# Epoch 6/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 7/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 8/100
# 596/596 [==============================] - 63s 105ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 9/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 10/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 11/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 12/100
# 596/596 [==============================] - 62s 104ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 13/100
# 596/596 [==============================] - 62s 104ms/step - loss: 9.7734e-04 - val_loss: 9.4263e-04
# Epoch 14/100
# 596/596 [==============================] - 62s 104ms/step - loss: 8.7593e-04 - val_loss: 8.9491e-04
# Epoch 15/100
# 596/596 [==============================] - 63s 105ms/step - loss: 7.9202e-04 - val_loss: 8.0824e-04
# Epoch 16/100
# 596/596 [==============================] - 63s 105ms/step - loss: 7.1814e-04 - val_loss: 7.4633e-04
# Epoch 17/100
# 596/596 [==============================] - 62s 104ms/step - loss: 6.6225e-04 - val_loss: 6.4743e-04
# Epoch 18/100
# 596/596 [==============================] - 62s 104ms/step - loss: 6.1787e-04 - val_loss: 6.0070e-04
# Epoch 19/100
# 596/596 [==============================] - 62s 104ms/step - loss: 5.6857e-04 - val_loss: 6.2326e-04
# Epoch 20/100
# 596/596 [==============================] - 62s 104ms/step - loss: 5.3660e-04 - val_loss: 5.4275e-04
# Epoch 21/100
# 596/596 [==============================] - 62s 104ms/step - loss: 4.9552e-04 - val_loss: 4.9012e-04
# Epoch 22/100
# 596/596 [==============================] - 62s 104ms/step - loss: 4.7201e-04 - val_loss: 4.7559e-04
# Epoch 23/100
# 596/596 [==============================] - 62s 104ms/step - loss: 4.4774e-04 - val_loss: 4.9705e-04
# Epoch 24/100
# 596/596 [==============================] - 62s 104ms/step - loss: 4.1814e-04 - val_loss: 4.0899e-04
# Epoch 25/100
# 596/596 [==============================] - 62s 104ms/step - loss: 4.0796e-04 - val_loss: 3.9384e-04
# Epoch 26/100
# 596/596 [==============================] - 62s 104ms/step - loss: 3.7548e-04 - val_loss: 3.8135e-04
# Epoch 27/100
# 596/596 [==============================] - 62s 104ms/step - loss: 3.6322e-04 - val_loss: 3.5507e-04
# Epoch 28/100
# 596/596 [==============================] - 62s 104ms/step - loss: 3.4733e-04 - val_loss: 3.9982e-04
# Epoch 29/100
# 596/596 [==============================] - 62s 104ms/step - loss: 3.3368e-04 - val_loss: 3.4061e-04
# Epoch 30/100
# 596/596 [==============================] - 62s 104ms/step - loss: 3.2079e-04 - val_loss: 3.8603e-04
# Epoch 31/100
# 596/596 [==============================] - 62s 104ms/step - loss: 3.0905e-04 - val_loss: 3.1772e-04
# Epoch 32/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.9445e-04 - val_loss: 2.9533e-04
# Epoch 33/100
# 596/596 [==============================] - 63s 105ms/step - loss: 2.8938e-04 - val_loss: 2.8976e-04
# Epoch 34/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.7469e-04 - val_loss: 2.7323e-04
# Epoch 35/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.7013e-04 - val_loss: 2.7756e-04
# Epoch 36/100
# 596/596 [==============================] - 63s 105ms/step - loss: 2.5739e-04 - val_loss: 2.6133e-04
# Epoch 37/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.4836e-04 - val_loss: 2.5114e-04
# Epoch 38/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.4185e-04 - val_loss: 2.5393e-04
# Epoch 39/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.3900e-04 - val_loss: 2.4739e-04
# Epoch 40/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.2734e-04 - val_loss: 2.4495e-04
# Epoch 41/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.2330e-04 - val_loss: 2.2958e-04
# Epoch 42/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.1899e-04 - val_loss: 2.2762e-04
# Epoch 43/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.1063e-04 - val_loss: 2.1928e-04
# Epoch 44/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.0953e-04 - val_loss: 2.0773e-04
# Epoch 45/100
# 596/596 [==============================] - 62s 104ms/step - loss: 2.0275e-04 - val_loss: 2.4921e-04
# Epoch 46/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.9589e-04 - val_loss: 2.0246e-04
# Epoch 47/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.9314e-04 - val_loss: 2.6737e-04
# Epoch 48/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.8777e-04 - val_loss: 1.8892e-04
# Epoch 49/100
# 596/596 [==============================] - 63s 105ms/step - loss: 1.8554e-04 - val_loss: 1.9419e-04
# Epoch 50/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.8336e-04 - val_loss: 2.3420e-04
# Epoch 51/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.7483e-04 - val_loss: 1.7807e-04
# Epoch 52/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.7521e-04 - val_loss: 2.2583e-04
# Epoch 53/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.7209e-04 - val_loss: 1.7712e-04
# Epoch 54/100
# 596/596 [==============================] - 63s 105ms/step - loss: 1.6743e-04 - val_loss: 1.7512e-04
# Epoch 55/100
# 596/596 [==============================] - 63s 105ms/step - loss: 1.6250e-04 - val_loss: 1.7690e-04
# Epoch 56/100
# 596/596 [==============================] - 63s 105ms/step - loss: 1.6190e-04 - val_loss: 1.6576e-04
# Epoch 57/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.5946e-04 - val_loss: 1.6729e-04
# Epoch 58/100
# 596/596 [==============================] - 63s 105ms/step - loss: 1.5743e-04 - val_loss: 1.6065e-04
# Epoch 59/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.5240e-04 - val_loss: 1.7289e-04
# Epoch 60/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.5268e-04 - val_loss: 1.7940e-04
# Epoch 61/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.4794e-04 - val_loss: 1.5517e-04
# Epoch 62/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.4469e-04 - val_loss: 1.5459e-04
# Epoch 63/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.4501e-04 - val_loss: 1.5358e-04
# Epoch 64/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.3931e-04 - val_loss: 1.4993e-04
# Epoch 65/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.4369e-04 - val_loss: 1.4368e-04
# Epoch 66/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.3246e-04 - val_loss: 1.4685e-04
# Epoch 67/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.4489e-04 - val_loss: 1.4633e-04
# Epoch 68/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.3076e-04 - val_loss: 1.3994e-04
# Epoch 69/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.3113e-04 - val_loss: 1.3869e-04
# Epoch 70/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.2994e-04 - val_loss: 1.4210e-04
# Epoch 71/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.3373e-04 - val_loss: 1.3282e-04
# Epoch 72/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.2887e-04 - val_loss: 1.3377e-04
# Epoch 73/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.2034e-04 - val_loss: 1.3979e-04
# Epoch 74/100
# 596/596 [==============================] - 63s 105ms/step - loss: 1.2338e-04 - val_loss: 1.3404e-04
# Epoch 75/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.2312e-04 - val_loss: 1.3728e-04
# Epoch 76/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.1801e-04 - val_loss: 1.5241e-04
# Epoch 77/100
# 596/596 [==============================] - 62s 104ms/step - loss: 1.1827e-04 - val_loss: 1.5576e-04
# Epoch 78/100
# 596/596 [==============================] - 62s 105ms/step - loss: 1.1710e-04 - val_loss: 1.2511e-04
# Epoch 79/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.1792e-04 - val_loss: 1.2828e-04
# Epoch 80/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.2120e-04 - val_loss: 1.2244e-04
# Epoch 81/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.1043e-04 - val_loss: 1.2956e-04
# Epoch 82/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.1125e-04 - val_loss: 1.2071e-04
# Epoch 83/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.1131e-04 - val_loss: 1.2756e-04
# Epoch 84/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0896e-04 - val_loss: 1.2174e-04
# Epoch 85/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0953e-04 - val_loss: 1.2373e-04
# Epoch 86/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0807e-04 - val_loss: 1.3223e-04
# Epoch 87/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0613e-04 - val_loss: 3.2961e-04
# Epoch 88/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0522e-04 - val_loss: 1.1957e-04
# Epoch 89/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0533e-04 - val_loss: 1.1878e-04
# Epoch 90/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0312e-04 - val_loss: 1.1828e-04
# Epoch 91/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0206e-04 - val_loss: 1.1350e-04
# Epoch 92/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.0001e-04 - val_loss: 1.4106e-04
# Epoch 93/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.0059e-04 - val_loss: 1.1529e-04
# Epoch 94/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0017e-04 - val_loss: 1.1495e-04
# Epoch 95/100
# 596/596 [==============================] - 61s 103ms/step - loss: 9.6756e-05 - val_loss: 1.1203e-04
# Epoch 96/100
# 596/596 [==============================] - 62s 103ms/step - loss: 1.0002e-04 - val_loss: 1.1634e-04
# Epoch 97/100
# 596/596 [==============================] - 61s 103ms/step - loss: 1.0151e-04 - val_loss: 1.0885e-04
# Epoch 98/100
# 596/596 [==============================] - 61s 103ms/step - loss: 9.3969e-05 - val_loss: 1.3721e-04
# Epoch 99/100
# 596/596 [==============================] - 62s 104ms/step - loss: 9.6786e-05 - val_loss: 1.0806e-04
# Epoch 100/100
# 596/596 [==============================] - 62s 103ms/step - loss: 9.5935e-05 - val_loss: 1.0955e-04

# %%
#TEST DEL MODELLO SUL TEST SET
predict = model.predict(X_test_noisy)
# Out:
# 83/83 [==============================] - 7s 58ms/step

# %%
predict.shape
# Out:
# (2647, 64, 64, 3)

# %%
n=10

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TEST SET
plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_test[i].reshape(64, 64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TEST SET COL RUMORE
plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_test_noisy[i].reshape(64, 64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#STAMPO LE PRIME DIECI IMMAGINI DEL TEST SET SENZA RUMORE (OUTPUT DELLA UNET)
plt.figure(figsize=(64, 64))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(predict[i].reshape(64, 64,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
NUMBER_OF_TEST_IMAGES = len(X_test)

mse = mean_squared_error(X_test.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3), predict.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3))
mae = mean_absolute_error(X_test.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3), predict.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3))
rmse = np.sqrt(mean_squared_error(X_test.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3), predict.reshape(NUMBER_OF_TEST_IMAGES, 64*64*3)))

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 0.000107444845
# Mean Absolute Error: 0.0064008273
# Root Mean Squared Error: 0.010365561

# %%
plt.figure(figsize = (11,7))
x = ["MSE","MAE","RMSE"]
y = [mse,mae,rmse]
plt.barh(x, y)
  
for index, value in enumerate(y):
    plt.text(value, index,
             str(value)[:7])
plt.show()
